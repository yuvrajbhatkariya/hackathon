# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
customers = pd.read_csv("EDA-Phase-1/customers.csv")
accounts = pd.read_csv("EDA-Phase-1/accounts.csv")
linkage = pd.read_csv("EDA-Phas -1/customer_account_linkage.csv")
products = pd.read_csv("EDA-Phase-1/product_details.csv")
labels = pd.read_csv("EDA-Phase-1/train_labels.csv")
test = pd.read_csv("EDA-Phase-1/test_accounts.csv")

# Transactions are split across 6 files due to GitHub size limits — concatenate them
transactions = pd.concat(
    [pd.read_csv(f"EDA-Phase-1/transactions_part_{i}.csv") for i in range(6)],
    ignore_index=True
)

# %%
# for name, df in [("customers", customers), ("accounts", accounts),
#                  ("linkage", linkage), ("products", products),
#                  ("labels", labels), ("transactions", transactions)]:
#     print(f"\n{'='*40}")
#     print(f"{name}: {df.shape}")
#     print(df.dtypes)
#     print(f"\nMissing values:\n{df.isnull().sum()}")

# %%
print(labels["is_mule"].value_counts())
print(f"Mule rate: {labels['is_mule'].mean():.4f}")
# Out:
# is_mule
# 0    23760
# 1      263
# Name: count, dtype: int64
# Mule rate: 0.0109

# %%
labels.sample(10)
# Out:
#         account_id  is_mule mule_flag_date alert_reason  flagged_by_branch
# 23443  ACCT_167879        0            NaN          NaN                NaN
# 3551   ACCT_196409        0            NaN          NaN                NaN
# 21565  ACCT_187961        0            NaN          NaN                NaN
# 5101   ACCT_013282        0            NaN          NaN                NaN
# 19082  ACCT_134823        0            NaN          NaN                NaN
# 8961   ACCT_009310        0            NaN          NaN                NaN
# 19642  ACCT_171726        0            NaN          NaN                NaN
# 21274  ACCT_006755        0            NaN          NaN                NaN
# 14665  ACCT_103835        0            NaN          NaN                NaN
# 1700   ACCT_104494        0            NaN          NaN                NaN

# %%
labels.isnull().sum()
# Out:
# account_id               0
# is_mule                  0
# mule_flag_date       23760
# alert_reason         23781
# flagged_by_branch    23760
# dtype: int64

# %%
labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24023 entries, 0 to 24022
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   account_id         24023 non-null  object
#  1   is_mule            24023 non-null  int64
#  2   mule_flag_date     263 non-null    object
#  3   alert_reason       242 non-null    object
#  4   flagged_by_branch  263 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 938.5+ KB

# %%
labels.account_id.nunique()
# Out:
# 24023

# %%
for col in labels.columns.drop(["account_id"]):
    print(f"{col}: {labels[col].nunique()}")
# Out:
# is_mule: 2
# mule_flag_date: 172
# alert_reason: 13
# flagged_by_branch: 162

# %%
labels.notnull().sum()
# Out:
# account_id           24023
# is_mule              24023
# mule_flag_date         263
# alert_reason           242
# flagged_by_branch      263
# dtype: int64

# %%
test.info()
test.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16015 entries, 0 to 16014
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   account_id  16015 non-null  object
# dtypes: object(1)
# memory usage: 125.2+ KB
#         account_id
# 7137   ACCT_087477
# 2958   ACCT_198608
# 12288  ACCT_042908
# 15604  ACCT_090495
# 10765  ACCT_035541
# 13547  ACCT_050095
# 3111   ACCT_073626
# 15087  ACCT_030776
# 4403   ACCT_011286
# 6996   ACCT_153456

# %%
customers.sample(5)
# Out:
#        customer_id date_of_birth relationship_start_date pan_available  \
# 27701  CUST_137205    1959-11-10              2021-10-22             Y
# 9071   CUST_045207    1983-11-29              2006-04-21             Y
# 4960   CUST_024470    1994-09-17              2010-12-12           NaN
# 2944   CUST_014519    1948-02-28              2017-03-05             Y
# 6789   CUST_033511    1975-12-16              2009-06-27             Y
#
#       aadhaar_available passport_available mobile_banking_flag  \
# 27701               NaN                  N                   N
# 9071                  Y                  N                   Y
# 4960                NaN                  N                   N
# 2944                  N                  N                   Y
# 6789                  N                  N                   N
#
#       internet_banking_flag atm_card_flag demat_flag credit_card_flag  \
# 27701                     N             Y          N                N
# ...

# %%
customers.isnull().sum()
# Out:
# customer_id                   0
# date_of_birth                 0
# relationship_start_date       0
# pan_available              5732
# aadhaar_available          9708
# passport_available            0
# mobile_banking_flag           0
# internet_banking_flag         0
# atm_card_flag                 0
# demat_flag                    0
# credit_card_flag              0
# fastag_flag                   0
# customer_pin                  0
# permanent_pin                 0
# dtype: int64

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39988 entries, 0 to 39987
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              39988 non-null  object
#  1   date_of_birth            39988 non-null  object
#  2   relationship_start_date  39988 non-null  object
#  3   pan_available            34256 non-null  object
#  4   aadhaar_available        30280 non-null  object
#  5   passport_available       39988 non-null  object
#  6   mobile_banking_flag      39988 non-null  object
#  7   internet_banking_flag    39988 non-null  object
#  8   atm_card_flag            39988 non-null  object
#  9   demat_flag               39988 non-null  object
#  10  credit_card_flag         39988 non-null  object
#  11  fastag_flag              39988 non-null  object
#  12  customer_pin             39988 non-null  int64
#  13  permanent_pin            39988 non-null  int64
# ...

# %%
customers.customer_id.nunique()
# Out:
# 39988

# %%
accounts.sample(10)
# Out:
#         account_id account_status  product_code  currency_code  \
# 12863  ACCT_064148         active           169              1
# 29785  ACCT_148319         active           187              1
# 22947  ACCT_113853         frozen           191              1
# 9400   ACCT_047167         active           100              1
# 4449   ACCT_021975         active           169              1
# 25827  ACCT_128466         active           101              1
# 7568   ACCT_037538         active           193              1
# 5204   ACCT_025828         active           113              1
# 19339  ACCT_095928         active           187              1
# 24615  ACCT_122178         active           191              1
#
#       account_opening_date  branch_code  branch_pin  avg_balance  \
# 12863           2023-11-09         5114    248046.0     17334.69
# 29785           2017-04-21         4400    342039.0     17656.87
# 22947           2023-07-24         4249    400007.0    -33974.40
# ...

# %%
accounts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40038 entries, 0 to 40037
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   account_id               40038 non-null  object
#  1   account_status           40038 non-null  object
#  2   product_code             40038 non-null  int64
#  3   currency_code            40038 non-null  int64
#  4   account_opening_date     40038 non-null  object
#  5   branch_code              40038 non-null  int64
#  6   branch_pin               38029 non-null  float64
#  7   avg_balance              38835 non-null  float64
#  8   product_family           40038 non-null  object
#  9   nomination_flag          40038 non-null  object
#  10  cheque_allowed           40038 non-null  object
#  11  cheque_availed           40038 non-null  object
#  12  num_chequebooks          40038 non-null  int64
#  13  last_mobile_update_date  6037 non-null   object
# ...

# %%
accounts.isnull().sum()
# Out:
# account_id                     0
# account_status                 0
# product_code                   0
# currency_code                  0
# account_opening_date           0
# branch_code                    0
# branch_pin                  2009
# avg_balance                 1203
# product_family                 0
# nomination_flag                0
# cheque_allowed                 0
# cheque_availed                 0
# num_chequebooks                0
# last_mobile_update_date    34001
# kyc_compliant                  0
# last_kyc_date                  0
# rural_branch                   0
# monthly_avg_balance         1203
# quarterly_avg_balance          0
# daily_avg_balance              0
# freeze_date                38721
# unfreeze_date              39613
# dtype: int64

# %%
accounts.account_id.nunique()
# Out:
# 40038

# %%
products.sample(5)
# Out:
#        customer_id   loan_sum  loan_count    cc_sum  cc_count  od_sum  \
# 6265   CUST_030926        NaN           0 -42421.42         2     0.0
# 33152  CUST_164322        NaN           0       NaN         0     0.0
# 29029  CUST_143916 -466813.34           3       NaN         0     0.0
# 5757   CUST_028363        NaN           0       NaN         0     0.0
# 513    CUST_002432        NaN           0 -56926.83         2     0.0
#
#        od_count   ka_sum  ka_count     sa_sum  sa_count
# 6265          0  5988.42         1       0.00         0
# 33152         0     0.00         0       0.00         1
# 29029         0     0.00         0     334.93         1
# 5757          0     0.00         0    9956.36         1
# 513           0     0.00         0  106001.43         1

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39988 entries, 0 to 39987
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  39988 non-null  object
#  1   loan_sum     8503 non-null   float64
#  2   loan_count   39988 non-null  int64
#  3   cc_sum       6301 non-null   float64
#  4   cc_count     39988 non-null  int64
#  5   od_sum       39988 non-null  float64
#  6   od_count     39988 non-null  int64
#  7   ka_sum       39988 non-null  float64
#  8   ka_count     39988 non-null  int64
#  9   sa_sum       39988 non-null  float64
#  10  sa_count     39988 non-null  int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 3.4+ MB

# %%
products.customer_id.nunique()
# Out:
# 39988

# %%
products.isnull().sum()
# Out:
# customer_id        0
# loan_sum       31485
# loan_count         0
# cc_sum         33687
# cc_count           0
# od_sum             0
# od_count           0
# ka_sum             0
# ka_count           0
# sa_sum             0
# sa_count           0
# dtype: int64

# %%
customers.customer_id.nunique()
# Out:
# 39988

# %%
linkage.sample(5)
# Out:
#        customer_id   account_id
# 14694  CUST_073010  ACCT_073224
# 22703  CUST_112362  ACCT_112699
# 8593   CUST_042613  ACCT_042734
# 22595  CUST_111816  ACCT_112151
# 13971  CUST_069521  ACCT_069725

# %%
linkage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40038 entries, 0 to 40037
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  40038 non-null  object
#  1   account_id   40038 non-null  object
# dtypes: object(2)
# memory usage: 625.7+ KB

# %%
linkage.customer_id.nunique(), linkage.account_id.nunique()
# Out:
# (39988, 40038)

# %%
transactions.sample(20)
# Out:
#         transaction_id   account_id transaction_timestamp  mcc_code channel  \
# 1195069   TXN_28244636  ACCT_154101   2023-03-16T16:08:28      2017     UPD
# 323380    TXN_16511138  ACCT_089823   2021-07-05T20:01:35      6300     UPD
# 1220866   TXN_25821895  ACCT_140772   2023-03-25T18:42:07      9355     UPD
# 1049708   TXN_24923390  ACCT_136054   2023-01-10T15:00:16      6011     UPD
# 4809004   TXN_26035874  ACCT_142097   2024-10-04T11:42:52      2199     UPC
# 6547249   TXN_06120270  ACCT_033152   2025-04-08T11:43:24      5905     UPD
# 6291193   TXN_10644629  ACCT_057299   2025-03-14T01:25:41      5651     UPD
# 467388    TXN_27259937  ACCT_148633   2021-11-17T15:15:44      9384     APD
# 3182415   TXN_21619029  ACCT_118079   2024-03-18T17:03:49      9384     UPD
# 4912488   TXN_21482725  ACCT_117296   2024-10-16T14:48:17      9384     UPC
# 4689637   TXN_24004524  ACCT_131163   2024-09-20T10:15:54      9355     UPD
# ...

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7424845 entries, 0 to 7424844
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   transaction_id         object
#  1   account_id             object
#  2   transaction_timestamp  object
#  3   mcc_code               int64
#  4   channel                object
#  5   amount                 float64
#  6   txn_type               object
#  7   counterparty_id        object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 453.2+ MB

# %%
transactions.isnull().sum()
# Out:
# transaction_id           0
# account_id               0
# transaction_timestamp    0
# mcc_code                 0
# channel                  0
# amount                   0
# txn_type                 0
# counterparty_id          0
# dtype: int64

# %%
transactions.account_id.nunique()
# Out:
# 39605

# %%
transactions.transaction_id.nunique(), transactions.account_id.nunique()
# Out:
# (7424845, 39605)
